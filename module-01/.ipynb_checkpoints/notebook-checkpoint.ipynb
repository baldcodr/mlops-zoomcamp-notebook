# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !python --version
# Out:
# Python 3.9.12

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    #çompute trip duration in minutes
    df["duration_in_mins"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration_in_mins = df.duration_in_mins.apply(lambda td: td.total_seconds()/60)

    #Select all trips less than 60
    df = df[(df.duration_in_mins>=1) & (df.duration_in_mins <=60)]

    #Extract the most useful categorical and numerical variables from our dataset
    categorical = ['PULocationID','DOLocationID']

    #Convert numerical variables to categorical variables
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe("./data/green_tripdata_2022-01.parquet")
df_val = read_dataframe("./data/green_tripdata_2022-02.parquet")
df_train.shape, df_val.shape
# Out:
# ((59603, 21), (66097, 21))

# %%
#Visualize trips less than 60
ldf = df_train
ldf = ldf[(ldf.duration_in_mins>=1) & (ldf.duration_in_mins <=60)]
sns.displot(data =  ldf, x = "duration_in_mins", hue="VendorID")

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error
import pickle

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("ny-taxi-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='ny-taxi-experiment', tags={}>

# %%
#combine the pickup and drop off location ids 
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
#Extract the most useful categorical and numerical variables from our dataset
# categorical = ['PULocationID','DOLocationID']
categorical = ['PU_DO']
numerical = ['trip_distance']

#perform data vectorization
dv = DictVectorizer()

#print out the features
# print(len(dv.feature_names_))

#Convert our selected features to dictionaries for our vectorizers to work
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

#Convert our selected features to dictionaries for our vectorizers to work
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration_in_mins'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
#Lasso regression
with mlflow.start_run():
    #set developer tag name
    mlflow.set_tag("developer", "David")
    mlflow.set_tag("model", "Lasso Regression")

    #specify training and validation data path
    mlflow.log_param("train-data-path", "./data/green_tripdata_2022-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2022-02.parquet")

    #log model parameter alpha
    alpha = 0.001
    mlflow.log_param("alpha", alpha)

    #train our model
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    #model prediction
    y_pred = lr.predict(X_train)


    #evaluate our model
    rmse = mean_squared_error(y_train, y_pred, squared=False)

    #log model metric 
    mlflow.log_metric("rmse", rmse)
    print(rmse)
# Out:
# 6.926543641418329

# %%
#Use Linear Regreassion as our baseline

#train our model
lr = LinearRegression()
lr.fit(X_train, y_train)

#model prediction
y_pred = lr.predict(X_train)

#evaluate our model
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 4.9985053565382715

# %%
#save model for deployment

with open('models/lin_reg.bin', 'wb') as m_out:
    pickle.dump((dv,lr), m_out)

# %%
#Ridge regression

#train our model
lr = Ridge(alpha=0.0005)
lr.fit(X_train, y_train)

#model prediction
y_pred = lr.predict(X_train)

#evaluate our model
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.43591924993184

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):

    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
# from math import exp
# exp( -2)
# Out:
# 0.1353352832366127

# %%
search_space = {
    'ma_depth': scope.int(hp.quniform('max_depth',4 , 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -1, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda':hp.loguniform('reg_lambda',-6, -1) ,
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [10:05:32] WARNING: ../src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [10:05:32] WARNING: ../src/learner.cc:576:
# Parameters: { "ma_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation-rmse:6.23424
# [1]	validation-rmse:6.17549
# [2]	validation-rmse:6.14726
# [3]	validation-rmse:6.13328
# [4]	validation-rmse:6.12482
# [5]	validation-rmse:6.11682
# [6]	validation-rmse:6.11060
# [7]	validation-rmse:6.10955
# [8]	validation-rmse:6.10191
# [9]	validation-rmse:6.09654
# [10]	validation-rmse:6.09355
# [11]	validation-rmse:6.09245
# [12]	validation-rmse:6.08879
# [13]	validation-rmse:6.08475
# [14]	validation-rmse:6.07974
# [15]	validation-rmse:6.08025
# [16]	validation-rmse:6.07934
# [17]	validation-rmse:6.07750
# [18]	validation-rmse:6.07041
# [19]	validation-rmse:6.06474
# [20]	validation-rmse:6.05917
# [21]	validation-rmse:6.05182
# [22]	validation-rmse:6.05153
# [23]	validation-rmse:6.05479
# [24]	validation-rmse:6.04951
# [25]	validation-rmse:6.03743
# [26]	validation-rmse:6.03627
# [27]	validation-rmse:6.03437
# [28]	validation-rmse:6.03463
# [29]	validation-rmse:6.03440
# [30]	validation-rmse:6.03412
# [31]	validation-rmse:6.03434
# [32]	validation-rmse:6.03240
# [33]	validation-rmse:6.02794
# [34]	validation-rmse:6.02754
# [35]	validation-rmse:6.02810
# [36]	validation-rmse:6.02700
# [37]	validation-rmse:6.02614
# [38]	validation-rmse:6.02771
# [39]	validation-rmse:6.02381
# [40]	validation-rmse:6.01809
# [41]	validation-rmse:6.01507
# [42]	validation-rmse:6.01612
# [43]	validation-rmse:6.01558
# [44]	validation-rmse:6.01433
# [45]	validation-rmse:6.00448
# [46]	validation-rmse:6.00220
# [47]	validation-rmse:6.00212
# [48]	validation-rmse:6.00182
# [49]	validation-rmse:5.99642
# [50]	validation-rmse:5.99206
# [51]	validation-rmse:5.99244
# [52]	validation-rmse:5.99456
# [53]	validation-rmse:5.99549
# [54]	validation-rmse:5.99853
# [55]	validation-rmse:6.00004
# [56]	validation-rmse:6.00014
# [57]	validation-rmse:5.99950
# [58]	validation-rmse:5.99731
# [59]	validation-rmse:5.99691
# [60]	validation-rmse:5.99605
# [61]	validation-rmse:5.99631
# [62]	validation-rmse:5.99668
# [63]	validation-rmse:5.99651
# [64]	validation-rmse:5.99791
# [65]	validation-rmse:5.99821
# [66]	validation-rmse:5.99785
# [67]	validation-rmse:5.99711
# [68]	validation-rmse:5.99718
# [69]	validation-rmse:5.98587
# [70]	validation-rmse:5.98466
# [71]	validation-rmse:5.98337
# [72]	validation-rmse:5.98324
# [73]	validation-rmse:5.98129
# [74]	validation-rmse:5.97998
# [75]	validation-rmse:5.97951
# [76]	validation-rmse:5.98060
# [77]	validation-rmse:5.97906
# [78]	validation-rmse:5.97743
# [79]	validation-rmse:5.97589
# [80]	validation-rmse:5.97564
# [81]	validation-rmse:5.97617
# [82]	validation-rmse:5.97672
# [83]	validation-rmse:5.97631
# [84]	validation-rmse:5.97419
# [85]	validation-rmse:5.97167
# [86]	validation-rmse:5.97224
# [87]	validation-rmse:5.97085
# [88]	validation-rmse:5.96710
# [89]	validation-rmse:5.96528
# [90]	validation-rmse:5.96384
# [91]	validation-rmse:5.96301
# [92]	validation-rmse:5.96196
# [93]	validation-rmse:5.96323
# [94]	validation-rmse:5.96211
# [95]	validation-rmse:5.96169
# [96]	validation-rmse:5.96298
# [97]	validation-rmse:5.96415
# [98]	validation-rmse:5.96441
# [99]	validation-rmse:5.96353
# [100]	validation-rmse:5.96506
# [101]	validation-rmse:5.96611
# [102]	validation-rmse:5.96602
# [103]	validation-rmse:5.96055
# [104]	validation-rmse:5.95888
# [105]	validation-rmse:5.95952
# [106]	validation-rmse:5.96108
# [107]	validation-rmse:5.96163
# [108]	validation-rmse:5.96195
# [109]	validation-rmse:5.96216
# [110]	validation-rmse:5.96139
# [111]	validation-rmse:5.96152
# [112]	validation-rmse:5.96148
# [113]	validation-rmse:5.96173
# [114]	validation-rmse:5.96094
# [115]	validation-rmse:5.96122
# [116]	validation-rmse:5.96108
# [117]	validation-rmse:5.96076
# [118]	validation-rmse:5.96081
# [119]	validation-rmse:5.96209
# [120]	validation-rmse:5.96076
# [121]	validation-rmse:5.96153
# [122]	validation-rmse:5.96204
# [123]	validation-rmse:5.96206
# [124]	validation-rmse:5.96153
# [125]	validation-rmse:5.96049
# [126]	validation-rmse:5.95953
# [127]	validation-rmse:5.95777
# [128]	validation-rmse:5.96041
# [129]	validation-rmse:5.96017
# [130]	validation-rmse:5.96010
# [131]	validation-rmse:5.96064
# [132]	validation-rmse:5.95986
# [133]	validation-rmse:5.95877
# [134]	validation-rmse:5.95967
# [135]	validation-rmse:5.96127
# [136]	validation-rmse:5.96376
# [137]	validation-rmse:5.96347
# [138]	validation-rmse:5.96371
# [139]	validation-rmse:5.96295
# [140]	validation-rmse:5.96249
# [141]	validation-rmse:5.96171
# [142]	validation-rmse:5.96108
# [143]	validation-rmse:5.96176
# [144]	validation-rmse:5.96077
# [145]	validation-rmse:5.96472
# [146]	validation-rmse:5.96408
# [147]	validation-rmse:5.96423
# [148]	validation-rmse:5.96510
# [149]	validation-rmse:5.96476
# [150]	validation-rmse:5.96379
# [151]	validation-rmse:5.96377
# [152]	validation-rmse:5.96418
# [153]	validation-rmse:5.96118
# [154]	validation-rmse:5.95783
# [155]	validation-rmse:5.95776
# [156]	validation-rmse:5.95657
# [157]	validation-rmse:5.95618
# [158]	validation-rmse:5.95614
# [159]	validation-rmse:5.95545
# [160]	validation-rmse:5.95429
# [161]	validation-rmse:5.95404
# [162]	validation-rmse:5.95338
# [163]	validation-rmse:5.95186
# [164]	validation-rmse:5.95130
# [165]	validation-rmse:5.95130
# [166]	validation-rmse:5.95304
# [167]	validation-rmse:5.95325
# [168]	validation-rmse:5.95317
# [169]	validation-rmse:5.95274
# [170]	validation-rmse:5.95343
# [171]	validation-rmse:5.95265
# [172]	validation-rmse:5.95084
# [173]	validation-rmse:5.94923
# [174]	validation-rmse:5.95008
# [175]	validation-rmse:5.94965
# [176]	validation-rmse:5.94963
# [177]	validation-rmse:5.94850
# [178]	validation-rmse:5.94850
# [179]	validation-rmse:5.94800
# [180]	validation-rmse:5.94880
# [181]	validation-rmse:5.94726
# [182]	validation-rmse:5.94687
# [183]	validation-rmse:5.94677
# [184]	validation-rmse:5.94486
# [185]	validation-rmse:5.94485
# [186]	validation-rmse:5.94429
# [187]	validation-rmse:5.94370
# [188]	validation-rmse:5.94394
# [189]	validation-rmse:5.94493
# [190]	validation-rmse:5.94458
# [191]	validation-rmse:5.94401
# [192]	validation-rmse:5.94213
# [193]	validation-rmse:5.94192
# [194]	validation-rmse:5.94101
# [195]	validation-rmse:5.94111
# [196]	validation-rmse:5.94097
# [197]	validation-rmse:5.94044
# [198]	validation-rmse:5.93165
# [199]	validation-rmse:5.92897
# [200]	validation-rmse:5.92974
# [201]	validation-rmse:5.93021
# [202]	validation-rmse:5.93074
# [203]	validation-rmse:5.93119
# [204]	validation-rmse:5.93184
# [205]	validation-rmse:5.93234
# [206]	validation-rmse:5.93404
# [207]	validation-rmse:5.93325
# [208]	validation-rmse:5.93362
# [209]	validation-rmse:5.93436
# [210]	validation-rmse:5.93393
# [211]	validation-rmse:5.93439
# [212]	validation-rmse:5.93461
# [213]	validation-rmse:5.93430
# [214]	validation-rmse:5.93488
# [215]	validation-rmse:5.93492
# [216]	validation-rmse:5.93508
# [217]	validation-rmse:5.93444
# [218]	validation-rmse:5.93289
# [219]	validation-rmse:5.93422
# [220]	validation-rmse:5.93509
# [221]	validation-rmse:5.93490
# [222]	validation-rmse:5.93493
# [223]	validation-rmse:5.93499
# [224]	validation-rmse:5.93398
# [225]	validation-rmse:5.93302
# [226]	validation-rmse:5.93234
# [227]	validation-rmse:5.93262
# [228]	validation-rmse:5.93281
# [229]	validation-rmse:5.93264
# [230]	validation-rmse:5.93285
# [231]	validation-rmse:5.93550
# [232]	validation-rmse:5.93553
# [233]	validation-rmse:5.93546
# [234]	validation-rmse:5.93684
# [235]	validation-rmse:5.93607
# [236]	validation-rmse:5.93654
# [237]	validation-rmse:5.93622
# [238]	validation-rmse:5.93603
# [239]	validation-rmse:5.93783
# [240]	validation-rmse:5.93666
# [241]	validation-rmse:5.93691
# [242]	validation-rmse:5.93698
# [243]	validation-rmse:5.93638
# [244]	validation-rmse:5.93646
# [245]	validation-rmse:5.93560
# [246]	validation-rmse:5.93581
# [247]	validation-rmse:5.93620
# [248]	validation-rmse:5.93616
# [249]	validation-rmse:5.93663
# [10:05:39] WARNING: ../src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [10:05:39] WARNING: ../src/learner.cc:576:
# Parameters: { "ma_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation-rmse:9.95770
# [1]	validation-rmse:7.30058
# [2]	validation-rmse:6.48588
# [3]	validation-rmse:6.23541
# [4]	validation-rmse:6.13310
# [5]	validation-rmse:6.10326
# [6]	validation-rmse:6.09012
# [7]	validation-rmse:6.08212
# [8]	validation-rmse:6.07419
# [9]	validation-rmse:6.07015
# [10]	validation-rmse:6.06886
# [11]	validation-rmse:6.06489
# [12]	validation-rmse:6.06304
# [13]	validation-rmse:6.04868
# [14]	validation-rmse:6.04391
# [15]	validation-rmse:6.04036
# [16]	validation-rmse:6.03716
# [17]	validation-rmse:6.03157
# [18]	validation-rmse:6.02939
# [19]	validation-rmse:6.02620
# [20]	validation-rmse:6.02468
# [21]	validation-rmse:6.02215
# [22]	validation-rmse:6.02100
# [23]	validation-rmse:6.01941
# [24]	validation-rmse:6.01785
# [25]	validation-rmse:6.01344
# [26]	validation-rmse:6.01069
# [27]	validation-rmse:6.00916
# [28]	validation-rmse:6.00616
# [29]	validation-rmse:6.00504
# [30]	validation-rmse:6.00268
# [31]	validation-rmse:6.00048
# [32]	validation-rmse:5.99742
# [33]	validation-rmse:5.99589
# [34]	validation-rmse:5.98803
# [35]	validation-rmse:5.98643
# [36]	validation-rmse:5.98517
# [37]	validation-rmse:5.98309
# [38]	validation-rmse:5.98266
# [39]	validation-rmse:5.98033
# [40]	validation-rmse:5.97945
# [41]	validation-rmse:5.97885
# [42]	validation-rmse:5.97536
# [43]	validation-rmse:5.97246
# [44]	validation-rmse:5.97244
# [45]	validation-rmse:5.96934
# [46]	validation-rmse:5.96744
# [47]	validation-rmse:5.96535
# [48]	validation-rmse:5.96424
# [49]	validation-rmse:5.96361
# [50]	validation-rmse:5.96131
# [51]	validation-rmse:5.96046
# [52]	validation-rmse:5.95904
# [53]	validation-rmse:5.95764
# [54]	validation-rmse:5.95764
# [55]	validation-rmse:5.95787
# [56]	validation-rmse:5.95544
# [57]	validation-rmse:5.95431
# [58]	validation-rmse:5.95293
# [59]	validation-rmse:5.94948
# [60]	validation-rmse:5.94856
# ...
# [858]	validation-rmse:5.84261
# [859]	validation-rmse:5.84255
# [860]	validation-rmse:5.84258
# [861]	validation-rmse:5.84254
# [862]	validation-rmse:5.84280
# [863]	validation-rmse:5.84251
# [864]	validation-rmse:5.84237
# [865]	validation-rmse:5.84293
# [866]	validation-rmse:5.84287
# [867]	validation-rmse:5.84304
# [868]	validation-rmse:5.84449
# [869]	validation-rmse:5.84465
# [870]	validation-rmse:5.84486
# [871]	validation-rmse:5.84384
# [872]	validation-rmse:5.84390
# [873]	validation-rmse:5.84387
# [874]	validation-rmse:5.84434
# [875]	validation-rmse:5.84415
# [876]	validation-rmse:5.84429
# [877]	validation-rmse:5.84361
# [878]	validation-rmse:5.84369
# [879]	validation-rmse:5.84365
# [880]	validation-rmse:5.84360
# [881]	validation-rmse:5.84367
# [10:08:55] WARNING: ../src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [10:08:55] WARNING: ../src/learner.cc:576:
# Parameters: { "ma_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation-rmse:10.50704
# [1]	validation-rmse:7.68776
# [2]	validation-rmse:6.67716
# [3]	validation-rmse:6.32249
# [4]	validation-rmse:6.18411
# [5]	validation-rmse:6.13177
# [6]	validation-rmse:6.11306
# [7]	validation-rmse:6.08201
# [8]	validation-rmse:6.07528
# [9]	validation-rmse:6.06872
# [10]	validation-rmse:6.06559
# [11]	validation-rmse:6.06254
# [12]	validation-rmse:6.05894
# [13]	validation-rmse:6.05606
# [14]	validation-rmse:6.05665
# [15]	validation-rmse:6.05179
# [16]	validation-rmse:6.04823
# [17]	validation-rmse:6.04802
# [18]	validation-rmse:6.04821
# [19]	validation-rmse:6.04660
# [20]	validation-rmse:6.04493
# [21]	validation-rmse:6.04389
# [22]	validation-rmse:6.04296
# [23]	validation-rmse:6.04017
# [24]	validation-rmse:6.03912
# [25]	validation-rmse:6.03421
# [26]	validation-rmse:6.03260
# [27]	validation-rmse:6.03422
# [28]	validation-rmse:6.03383
# [29]	validation-rmse:6.03043
# [30]	validation-rmse:6.02870
# [31]	validation-rmse:6.02578
# [32]	validation-rmse:6.02377
# [33]	validation-rmse:6.01968
# [34]	validation-rmse:6.01949
# [35]	validation-rmse:6.01684
# [36]	validation-rmse:6.01577
# [37]	validation-rmse:6.01291
# [38]	validation-rmse:6.01089
# [39]	validation-rmse:6.00930
# [40]	validation-rmse:6.01071
# [41]	validation-rmse:6.00967
# [42]	validation-rmse:6.00978
# [43]	validation-rmse:6.00783
# [44]	validation-rmse:6.00788
# [45]	validation-rmse:6.00578
# [46]	validation-rmse:6.00457
# [47]	validation-rmse:6.00260
# [48]	validation-rmse:6.00301
# [49]	validation-rmse:6.00291
# [50]	validation-rmse:6.00100
# [51]	validation-rmse:5.99953
# [52]	validation-rmse:5.99877
# [53]	validation-rmse:5.99694
# [54]	validation-rmse:5.99627
# [55]	validation-rmse:5.99480
# [56]	validation-rmse:5.99267
# [57]	validation-rmse:5.99064
# [58]	validation-rmse:5.98969
# [59]	validation-rmse:5.98936
# [60]	validation-rmse:5.98904
# [61]	validation-rmse:5.98743
# [62]	validation-rmse:5.98651
# [63]	validation-rmse:5.98576
# [64]	validation-rmse:5.98416
# [65]	validation-rmse:5.98123
# [66]	validation-rmse:5.98109
# [67]	validation-rmse:5.97898
# [68]	validation-rmse:5.97894
# [69]	validation-rmse:5.97895
# [70]	validation-rmse:5.97858
# [71]	validation-rmse:5.97611
# [72]	validation-rmse:5.97495
# [73]	validation-rmse:5.97284
# [74]	validation-rmse:5.97248
# [75]	validation-rmse:5.97081
# [76]	validation-rmse:5.96927
# [77]	validation-rmse:5.96802
# [78]	validation-rmse:5.96639

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
